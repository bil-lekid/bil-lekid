# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# Hi my name is **Billy**
#
# Occupation: last year student soon to be unemployed :'(

# %% [markdown]
# *Data have exponentially taking over the world! In 2010, 2 zetabytes of data is either created, captured, copied, and consumed worldwide. Now in 2022 it is a whooping 97 ZETABYTES of data and soon in 2025 it would be 181 zetabytes, waiting to be data mined and used for cool stuff. I am an undergraduate in engineering physics, there I learned a lot of instrumentation and used a lot of simulation to learn and model building. One time a sudden thought came, isn't the sensor and AI technology getting more and more advanced as we are speaking. What if a simulation that would take hours to model the temperature in a building can be done in second? What if even unimportant data like the "rat killed by cars every year" or "How many dust you inhale" can be obtained in the near future? IT IS CERTAINLY A POSSIBILITY. So in preparation to that I want to be able to utilize and have a strong knowledge of what to do with data.*

# %% [markdown]
# ### Just a simple if statement to check length of string

# %%
statement = "If you are curious, answers will reveal itself"
if len(statement) > 10:
    print('haiya statement too long')

else:
    print("all good, statement not too long")
# Out:
# haiya statement too long

# %% [markdown]
# ----------
# - first
# - second
# - third
#
#
# [Press this link to obtain it all](https://www.youtube.com/watch?v=dQw4w9WgXcQ)
#
#
# ![IBM](https://cdn.iphoneincanada.ca/wp-content/uploads/2020/06/ibm.jpg)
# ```python
# print("hello world")
# ```
# > This is a quote
# ~~This is a strikethrough~~
